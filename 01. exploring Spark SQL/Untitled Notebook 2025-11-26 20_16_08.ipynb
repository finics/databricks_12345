# %%
dbutils.widgets.dropdown("combo_box", "Option1", ["Option1", "Option2", "Option3"], "Select an option")

# %%
dbutils.widgets.multiselect("multi_select", "Option1", ["Option1", "Option2", "Option3"], "Select multiple options")

dbutils.widgets.remove("sample_text")
